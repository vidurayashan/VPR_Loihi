# %%
import pandas as pd
import re
import json

# %%
import re
from collections import OrderedDict

def parse_log_content_fixed(file_content):
    datasets = OrderedDict()
    current_dataset = None
    current_sub_dataset = None
    temp_functions = []  # Temporary storage for functions before assigning to a sub-dataset
    temp_sub_dataset_info = None  # Temporary storage for sub-dataset information

    for line in file_content.split("\n"):
        line = line.strip()
        
        # Detect Main Dataset
        main_dataset_match = re.match(r'========== Evaluating (.+) ============', line)
        if main_dataset_match:
            current_dataset = main_dataset_match.group(1)
            datasets[current_dataset] = OrderedDict()
            current_sub_dataset = None
            temp_functions = []  # Reset temporary function storage
            temp_sub_dataset_info = None  # Reset temporary sub-dataset info
            continue
        
        # Detect function execution and store in temp list
        func_match = re.match(r'begin timestamp : [\d.]+; tag : ([^;]+); duration : ([\d.]+); package_0 : ([\d.]+); core_0 : ([\d.]+); uncore_0 : ([\d.]+)', line)
        if func_match:
            function_name = func_match.group(1)
            duration = float(func_match.group(2))
            package_0 = float(func_match.group(3))
            core_0 = float(func_match.group(4))
            uncore_0 = float(func_match.group(5))
            
            temp_functions.append({
                'function_name': function_name,
                'duration': duration,
                'package_0': package_0,
                'core_0': core_0,
                'uncore_0': uncore_0
            })
            continue
        
        # Detect Similarity computation results (sub-dataset identifier)
        similarity_match = re.match(r'(\S+) (.+) : ([\d.]+) - ([\d.]+) ms - db_size : (\d+)', line)
        if similarity_match:
            main_dataset, sub_dataset, accuracy, sim_time, db_size = similarity_match.groups()
            current_sub_dataset = sub_dataset.strip(" - ")  # Ensure correct sub dataset name format
            
            # Store sub-dataset information temporarily
            temp_sub_dataset_info = OrderedDict({
                'accuracy': float(accuracy),
                'similarity_computation_time_ms': float(sim_time),
                'db_size': int(db_size),
                'functions': temp_functions  # Assign stored function list
            })
            temp_functions = []  # Reset temporary function storage after assignment
            
            # Assign to dataset only after function measurements
            datasets[current_dataset][current_sub_dataset] = temp_sub_dataset_info
            temp_sub_dataset_info = None
            continue
    
    return datasets

def print_parsed_data(datasets):
    for dataset, sub_datasets in datasets.items():
        print(f'========== Evaluating {dataset} ============')
        for sub_dataset, details in sub_datasets.items():
            for func in details['functions']:
                print(f'begin timestamp : XXXX; tag : {func["function_name"]}; duration : {func["duration"]}; package_0 : {func["package_0"]}; core_0 : {func["core_0"]}; uncore_0 : {func["uncore_0"]}')
            print(f'{dataset} {sub_dataset} : {details["accuracy"]} - {details["similarity_computation_time_ms"]} ms - db_size : {details["db_size"]}')

# %%
file = "cpu_power_1.txt"

with open(file, "r") as file:
    file_content = file.read()

# %%
data = parse_log_content_fixed(file_content)
# print_parsed_data(data)
data
# Out:
# OrderedDict([('GardensPointWalking',
#               OrderedDict([('day_left - night_right',
#                             OrderedDict([('accuracy', 0.3483199833406223),
#                                          ('similarity_computation_time_ms',
#                                           2.49),
#                                          ('db_size', 200),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.024197816848754883,
#                                             'package_0': 527709.0,
#                                             'core_0': 419921.0,
#                                             'uncore_0': 21301.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 2.4869487285614014,
#                                             'package_0': 62893149.0,
#                                             'core_0': 53145983.0,
#                                             'uncore_0': 1697689.0}])])),
#                            ('day_right - night_right',
#                             OrderedDict([('accuracy', 0.6828675979541299),
#                                          ('similarity_computation_time_ms',
#                                           1.28),
#                                          ('db_size', 200),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.02676224708557129,
#                                             'package_0': 841367.0,
#                                             'core_0': 728270.0,
#                                             'uncore_0': 25757.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 1.2838332653045654,
#                                             'package_0': 28860339.0,
#                                             'core_0': 23747253.0,
#                                             'uncore_0': 947568.0}])])),
#                            ('day_right - day_left',
#                             OrderedDict([('accuracy', 0.766212373740079),
#                                          ('similarity_computation_time_ms',
#                                           1.17),
#                                          ('db_size', 200),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.022002220153808594,
#                                             'package_0': 486998.0,
#                                             'core_0': 411193.0,
#                                             'uncore_0': 12879.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 1.1654212474822998,
#                                             'package_0': 24475951.0,
#                                             'core_0': 19991221.0,
#                                             'uncore_0': 854673.0}])]))])),
#              ('CMU',
#               OrderedDict([('20110421 - 20100901',
#                             OrderedDict([('accuracy', 0.5329386692450612),
#                                          ('similarity_computation_time_ms',
#                                           43.18),
#                                          ('db_size', 1155),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.022441387176513672,
#                                             'package_0': 470824.0,
#                                             'core_0': 397033.0,
#                                             'uncore_0': 11657.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 315.63710165023804,
#                                             'package_0': 5516074868.0,
#                                             'core_0': 4213506486.0,
#                                             'uncore_0': 192879939.0}])])),
#                            ('20110421 - 20100915',
#                             OrderedDict([('accuracy', 0.5564904835088946),
#                                          ('similarity_computation_time_ms',
#                                           55.38),
#                                          ('db_size', 1155),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023815393447875977,
#                                             'package_0': 470519.0,
#                                             'core_0': 384276.0,
#                                             'uncore_0': 11719.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 328.1015672683716,
#                                             'package_0': 4020384300.0,
#                                             'core_0': 2695793880.0,
#                                             'uncore_0': 189800295.0}])])),
#                            ('20110421 - 20101221',
#                             OrderedDict([('accuracy', 0.5817727341148954),
#                                          ('similarity_computation_time_ms',
#                                           47.34),
#                                          ('db_size', 1155),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.030823707580566406,
#                                             'package_0': 623900.0,
#                                             'core_0': 506469.0,
#                                             'uncore_0': 21667.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 262.52624320983887,
#                                             'package_0': 3979264410.0,
#                                             'core_0': 2900510275.0,
#                                             'uncore_0': 151623269.0}])])),
#                            ('20110421 - 20110202',
#                             OrderedDict([('accuracy', 0.479021682146223),
#                                          ('similarity_computation_time_ms',
#                                           41.81),
#                                          ('db_size', 1155),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023232698440551758,
#                                             'package_0': 464049.0,
#                                             'core_0': 381652.0,
#                                             'uncore_0': 15625.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 150.0830900669098,
#                                             'package_0': 2650612233.0,
#                                             'core_0': 2034006451.0,
#                                             'uncore_0': 91554758.0}])]))])),
#              ('SFUMountain',
#               OrderedDict([('dry - dusk',
#                             OrderedDict([('accuracy', 0.5872419484129473),
#                                          ('similarity_computation_time_ms',
#                                           7.4),
#                                          ('db_size', 385),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023700952529907227,
#                                             'package_0': 471984.0,
#                                             'core_0': 379943.0,
#                                             'uncore_0': 20202.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 14.235003232955933,
#                                             'package_0': 208780899.0,
#                                             'core_0': 149004563.0,
#                                             'uncore_0': 8600076.0}])])),
#                            ('dry - jan',
#                             OrderedDict([('accuracy', 0.4686050355891277),
#                                          ('similarity_computation_time_ms',
#                                           3.54),
#                                          ('db_size', 385),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023935794830322266,
#                                             'package_0': 526488.0,
#                                             'core_0': 399352.0,
#                                             'uncore_0': 30639.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 6.8179755210876465,
#                                             'package_0': 104504310.0,
#                                             'core_0': 75343191.0,
#                                             'uncore_0': 4400013.0}])])),
#                            ('dry - wet',
#                             OrderedDict([('accuracy', 0.5301685324766576),
#                                          ('similarity_computation_time_ms',
#                                           3.59),
#                                          ('db_size', 385),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023302316665649414,
#                                             'package_0': 463073.0,
#                                             'core_0': 377074.0,
#                                             'uncore_0': 16663.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 6.900888919830322,
#                                             'package_0': 107061921.0,
#                                             'core_0': 77340683.0,
#                                             'uncore_0': 4583728.0}])]))])),
#              ('Nordland1000',
#               OrderedDict([('spring - winter',
#                             OrderedDict([('accuracy', 0.4729145364123906),
#                                          ('similarity_computation_time_ms',
#                                           35.73),
#                                          ('db_size', 1000),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.02355813980102539,
#                                             'package_0': 475341.0,
#                                             'core_0': 386534.0,
#                                             'uncore_0': 17334.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 178.64694452285767,
#                                             'package_0': 3155338602.0,
#                                             'core_0': 2441068519.0,
#                                             'uncore_0': 105032141.0}])])),
#                            ('spring - summer',
#                             OrderedDict([('accuracy', 0.3958831912658727),
#                                          ('similarity_computation_time_ms',
#                                           18.54),
#                                          ('db_size', 1000),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.022846460342407227,
#                                             'package_0': 505919.0,
#                                             'core_0': 421996.0,
#                                             'uncore_0': 15930.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 92.70829224586487,
#                                             'package_0': 1765927853.0,
#                                             'core_0': 1385192255.0,
#                                             'uncore_0': 59077058.0}])])),
#                            ('summer - winter',
#                             OrderedDict([('accuracy', 0.17715338731683622),
#                                          ('similarity_computation_time_ms',
#                                           6.2),
#                                          ('db_size', 1000),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.025725603103637695,
#                                             'package_0': 557921.0,
#                                             'core_0': 452819.0,
#                                             'uncore_0': 28748.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 31.012305736541748,
#                                             'package_0': 575540946.0,
#                                             'core_0': 437826333.0,
#                                             'uncore_0': 21439215.0}])])),
#                            ('summer - fall',
#                             OrderedDict([('accuracy', 0.5614676123621529),
#                                          ('similarity_computation_time_ms',
#                                           20.31),
#                                          ('db_size', 1000),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023364782333374023,
#                                             'package_0': 537901.0,
#                                             'core_0': 458068.0,
#                                             'uncore_0': 8423.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 101.57363176345825,
#                                             'package_0': 1867642253.0,
#                                             'core_0': 1454615356.0,
#                                             'uncore_0': 63572103.0}])]))])),
#              ('StLucia',
#               OrderedDict([('100909_0845 - 180809_1545',
#                             OrderedDict([('accuracy', 0.2244936271962395),
#                                          ('similarity_computation_time_ms',
#                                           29.38),
#                                          ('db_size', 1409),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.026263952255249023,
#                                             'package_0': 504271.0,
#                                             'core_0': 413634.0,
#                                             'uncore_0': 15259.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 209.9217357635498,
#                                             'package_0': 3451176956.0,
#                                             'core_0': 2544608903.0,
#                                             'uncore_0': 132276639.0}])])),
#                            ('100909_1000 - 190809_1410',
#                             OrderedDict([('accuracy', 0.3171161873095705),
#                                          ('similarity_computation_time_ms',
#                                           29.47),
#                                          ('db_size', 1266),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.023635149002075195,
#                                             'package_0': 482787.0,
#                                             'core_0': 406493.0,
#                                             'uncore_0': 6592.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 209.9435203075409,
#                                             'package_0': 2798932227.0,
#                                             'core_0': 1915666239.0,
#                                             'uncore_0': 127985512.0}])])),
#                            ('100909_1210 - 210809_1210',
#                             OrderedDict([('accuracy', 0.4029583067331993),
#                                          ('similarity_computation_time_ms',
#                                           31.98),
#                                          ('db_size', 1284),
#                                          ('functions',
#                                           [{'function_name': 'multiple_run_dummy',
#                                             'duration': 0.024419784545898438,
#                                             'package_0': 742857.0,
#                                             'core_0': 638854.0,
#                                             'uncore_0': 14709.0},
#                                            {'function_name': 'multiple_run',
#                                             'duration': 192.68744349479675,
#                                             'package_0': 2335383914.0,
#                                             'core_0': 1535833348.0,
#                                             'uncore_0': 113565261.0}])]))]))])

# %%
# data

# %%
power_data = {}

for dataset in data:
    power_data[dataset] = {}
    for sub_dataset in data[dataset]:
        print(sub_dataset)
        power_data[dataset][sub_dataset] = {}
        dummy_power = 0
        workload_power = 0
        dynamic_power = 0
        for function in data[dataset][sub_dataset]['functions']:
            # print(function["function_name"])
            if function["function_name"] == "multiple_run_dummy":
                dummy_power = function["package_0"] / function["duration"]
                power_data[dataset][sub_dataset]["Static Power"] = dummy_power
            else:
                workload_power = function["package_0"] / function["duration"]
                power_data[dataset][sub_dataset]["Total Power"] = workload_power
      
        power_data[dataset][sub_dataset]["Dynamic Power"] = abs(power_data[dataset][sub_dataset]["Total Power"] - \
                power_data[dataset][sub_dataset]["Static Power"])
        
        power_data[dataset][sub_dataset]["Total Power"] /= 1000000
        power_data[dataset][sub_dataset]["Static Power"] /= 1000000
        power_data[dataset][sub_dataset]["Dynamic Power"] /= 1000000
# Out:
# day_left - night_right
# day_right - night_right
# day_right - day_left
# 20110421 - 20100901
# 20110421 - 20100915
# 20110421 - 20101221
# 20110421 - 20110202
# dry - dusk
# dry - jan
# dry - wet
# spring - winter
# spring - summer
# summer - winter
# summer - fall
# 100909_0845 - 180809_1545
# 100909_1000 - 190809_1410
# 100909_1210 - 210809_1210

# %%
power_data
# Out:
# {'GardensPointWalking': {'day_left - night_right': {'Static Power': 21.80812439809642,
#    'Total Power': 25.289282516242757,
#    'Dynamic Power': 3.4811581181463374},
#   'day_right - night_right': {'Static Power': 31.438578281926787,
#    'Total Power': 22.47981866488981,
#    'Dynamic Power': 8.95875961703698},
#   'day_right - day_left': {'Static Power': 22.13403904676867,
#    'Total Power': 21.00180604470379,
#    'Dynamic Power': 1.1322330020648763}},
#  'CMU': {'20110421 - 20100901': {'Static Power': 20.980164741899156,
#    'Total Power': 17.4760027866193,
#    'Dynamic Power': 3.5041619552798533},
#   '20110421 - 20100915': {'Static Power': 19.756927427204197,
#    'Total Power': 12.253474841561838,
#    'Dynamic Power': 7.503452585642358},
#   '20110421 - 20101221': {'Static Power': 20.240913536091085,
#    'Total Power': 15.157587147656507,
#    'Dynamic Power': 5.083326388434577},
#   '20110421 - 20110202': {'Static Power': 19.973960458679255,
#    'Total Power': 17.660965214790743,
#    'Dynamic Power': 2.3129952438885124}},
#  'SFUMountain': {'dry - dusk': {'Static Power': 19.914136337112332,
#    'Total Power': 14.666726489857364,
#    'Dynamic Power': 5.2474098472549695},
#   'dry - jan': {'Static Power': 21.995843619658544,
#    'Total Power': 15.327762570688845,
#    'Dynamic Power': 6.668081048969699},
#   'dry - wet': {'Static Power': 19.8724018149933,
#    'Total Power': 15.514221753714653,
#    'Dynamic Power': 4.358180061278647}},
#  'Nordland1000': {'spring - winter': {'Static Power': 20.177357126444694,
#    'Total Power': 17.662426919349176,
#    'Dynamic Power': 2.5149302070955186},
#   'spring - summer': {'Static Power': 22.14430561310723,
#    'Total Power': 19.04821899120644,
#    'Dynamic Power': 3.0960866219007857},
#   'summer - winter': {'Static Power': 21.6873827117821,
#    'Total Power': 18.558470011529685,
#    'Dynamic Power': 3.128912700252414},
#   'summer - fall': {'Static Power': 23.021870793620344,
#    'Total Power': 18.387077635948977,
#    'Dynamic Power': 4.634793157671366}},
#  'StLucia': {'100909_0845 - 180809_1545': {'Static Power': 19.200118668324876,
#    'Total Power': 16.440303065554456,
#    'Dynamic Power': 2.7598156027704217},
#   '100909_1000 - 190809_1410': {'Static Power': 20.426653538660183,
#    'Total Power': 13.331834309055672,
#    'Dynamic Power': 7.094819229604511},
#   '100909_1210 - 210809_1210': {'Static Power': 30.420292963836598,
#    'Total Power': 12.120062789992144,
#    'Dynamic Power': 18.300230173844458}}}
